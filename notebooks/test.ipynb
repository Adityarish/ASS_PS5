# %%
import pandas as pd

check = pd.read_csv('../data/processed/merged_data.csv')
# Out:
# /var/folders/mb/xcn1fzjx76ndcb617gpnmf3c0000gn/T/ipykernel_27349/620395781.py:3: DtypeWarning: Columns (0: ORIGIN_AIRPORT, 1: DESTINATION_AIRPORT, 2: ORIGIN_CITY, 3: ORIGIN_STATE) have mixed types. Specify dtype option on import or set low_memory=False.
#   check = pd.read_csv('../data/processed/merged_data.csv')

# %%
(check['CANCELLED']).unique()
# Out:
# array([0])
